# %% [markdown]
# # Metadata analysis of articles with low scores marked by Tagger
# This script takes the text file consisting PMIDs of the artices with low scores given by Tagger as an input and returns the text file with the metadata of the article. This metadata consists of Article PMID, Article title and Article Publication Type from the PubMed database. Analysis of these articles shows that the tool does not work as expected when the abstract of the article is absent.

# %%
from xlrd import open_workbook
import urllib
from Bio import Entrez
from xml.dom import minidom
import xml.etree.ElementTree as ET

Entrez.email = "kansara3@illinois.edu"


#Save results to Excel file
from pandas import DataFrame
PMID_list = []
ArticleTitle_list = []
Abstract_list = []
PublicationType_list = []

# Read list of PMIDs from txt file
PMID_list_file = open("D:/GRA/Data/STEP 3 Run Tagger and get predictions/Tagger processed groups/Abstract and Pub Type for unmatched/ne_unmatched_PMIDs.txt","r")

Result_file = open("D:/GRA/Data/STEP 3 Run Tagger and get predictions/Tagger processed groups/st_unmatched_results.csv","w")

heading = "PMID" + "," + "Title" + "," + "Publication Type" + "," + "Abstract" + "\n"
Result_file.write(heading)

for PMID in PMID_list_file.readlines():
    PMID = PMID.replace("\n","")
    print(PMID)

    # Pass PMIDs to PubMed API to get articles' metadata in XML format
    link = "https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=" + PMID + "&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y"
    print(link)
        
    f = urllib.request.urlopen(link)
    
    
    tree = ET.parse(f)
    doc = tree.getroot()    
    
    # Get the metadata from the PubMed API
    for child in doc:
        PMID_list = []
        
        for step_child in child:
            if step_child.tag == "MedlineCitation":
                for step_child_level_2 in step_child:
                    if step_child_level_2.tag == "PMID":
                        article_PMID =  step_child_level_2.text
                        PMID_list.append(article_PMID)
                    if step_child_level_2.tag == "Article":
                        for step_child_level_3 in step_child_level_2:
                            if step_child_level_3.tag == "ArticleTitle":
                                article_title = step_child_level_3.text
                            
                            # Check whether Abstract is present in the metadata    
                            if step_child_level_3.tag == "Abstract":
                                article_abstract_list = []
                                for step_child_level_4 in step_child_level_3:
                                    if step_child_level_4.tag == "AbstractText":
                                        article_abstract_list.append(step_child_level_4.text)
                            else:
                                article_abstract_list = []
                            
                            # Check for the Publication type of the article in PubMed database
                            if step_child_level_3.tag == "PublicationTypeList":
                                article_publication_type_list = []
                                for step_child_level_4 in step_child_level_3:
                                    article_publication_type_list.append(step_child_level_4.text)
                           
                                print(article_title)
                                article_title = article_title.replace(",","")
                                article_abstract = " ".join(str(x) for x in article_abstract_list)   
                                print(article_abstract)
                                article_publication_type = " ".join(str(x) for x in article_publication_type_list)   
                                article_abstract = article_abstract.replace(",","")
                                
                                print(article_publication_type)

                                article_string = article_PMID + "," + article_title + "," + article_publication_type + "," + article_abstract + "\n"
                                # Write the result into output file
                                Result_file.write(article_string)
                                
                                PMID_list.append(article_PMID)
                                ArticleTitle_list.append(article_title)
                                Abstract_list.append(article_abstract)
                                PublicationType_list.append(article_publication_type)
                                



df = DataFrame({'PMID': PMID_list , 'Article Title': ArticleTitle_list, 'Abstract': Abstract_list, 
                'Publication Type': PublicationType_list})
df = df[['PMID','Article Title', 'Abstract', 'Publication Type']]

df.to_excel("D:/GRA/Data/STEP 3 Run Tagger and get predictions/Tagger processed groups/Abstract and Pub Type for unmatched/ne_unmatched_abstract.xlsx", sheet_name='sheet1', index=False)
                                
Result_file.close()
# Out:
# 6352313
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=6352313&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Comparison of inhaled fenoterol and salbutamol in the prevention of exercise-induced asthma.
#
# Clinical Trial Comparative Study Journal Article
# 6352313
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=6352313&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Comparison of inhaled fenoterol and salbutamol in the prevention of exercise-induced asthma.
#
# Clinical Trial Comparative Study Journal Article
# 4865569
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4865569&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Treatment of otitis externa with a tropical steroid-antibiotic combination.
#
# Clinical Trial Journal Article
# 352668
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=352668&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Versus placebo in treatment of acute otitis externa.
#
# Clinical Trial Journal Article
# 17888920
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=17888920&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Sublingual compared with oral and vaginal misoprostol for termination of pregnancy with second-trimester fetal demise.
#
# Comparative Study Journal Article Randomized Controlled Trial
# 15207678
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15207678&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Oral misoprostol vs. vaginal misoprostol for termination of pregnancy with intrauterine fetal demise in the second-trimester.
#
# Clinical Trial Comparative Study Journal Article Randomized Controlled Trial
# 15919397
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15919397&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Second trimester abortion using intravaginal misoprostol.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 15491575
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15491575&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Intravaginal misoprostol for pregnancy termination.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 12443626
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=12443626&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Fondaparinux versus enoxaparin for prevention of venous thromboembolism.
#
# Comment Letter
# 3387763
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=3387763&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# [Usefulness of the addition of aspartate magnesium hydrochloride via intravenous route to beta mimetics in the treatment of threatened premature labor].
#
# Journal Article
# 20875388
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=20875388&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# N-acetylcysteine in critically ill patients undergoing contrast-enhanced computed tomography: a randomized trial.
#
# Letter Randomized Controlled Trial Research Support, Non-U.S. Gov't
# 1116357
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=1116357&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Auxiliary pain relief during suction curettage.
#
# Comparative Study Journal Article
# 8910086
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8910086&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Comparison of 0.5% and 1.0% lidocaine for abortions.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 18626277
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=18626277&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Hormonal response to dehydroepiandrosterone administration in schizophrenia: findings from a randomized, double-blind, placebo-controlled, crossover study.
#
# Letter Randomized Controlled Trial Research Support, Non-U.S. Gov't
# 15905743
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=15905743&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Therapeutic drug monitoring of nevirapine reduces pharmacokinetic variability but does not affect toxicity or virologic success in the ATHENA study.
#
# Clinical Trial Controlled Clinical Trial Letter
# 4769611
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4769611&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Awareness during anaesthesia: a comparison of anaesthesia with nitrous oxide-oxygen and nitrous oxide-oxygen with innovar.
#
# Comparative Study Journal Article
# 7618736
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=7618736&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# The effect of midazolam and lorazepam on postoperative recovery after cardiac surgery.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 10850950
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=10850950&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Glutamine supplementation and intestinal permeability in Crohn's disease.
#
# Clinical Trial Comment Letter Randomized Controlled Trial
# 8334854
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=8334854&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Diabetic neuropathy: effects of intensified glycaemic control with multiple insulin injections.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 1798230
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=1798230&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Determination of the glycemic threshold for the regression or prevention of diabetic microangiopathies, and the insulin injection regimen to establish strict glycemic control in NIDDM.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 19014818
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4176868&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Controlled trial of a diet high in unsaturated fat for prevention of atherosclerotic complications.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 13884081
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=13884081&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# A controlled clinical trial of a diet high in unsaturated fat. Preliminary observations.
#
# Journal Article
# 4189785
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4189785&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Diet and atherosclerosis.
#
# Clinical Trial Controlled Clinical Trial Journal Article
# 4178789
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4178789&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Diet and cardiovascular diseases.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 4896402
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4896402&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Diet high in unsaturated fat. A controlled clinical trial.
#
# Clinical Trial Journal Article
# 4892340
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4892340&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Prevention of coronary heart disease and other complications of arteriosclerosis by modified diet.
#
# Clinical Trial Journal Article Review
# 4177491
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4177491&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Trial of unsaturated-fat diet.
#
# Clinical Trial Controlled Clinical Trial Journal Article
# 13907771
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=13907771&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# A palatable diet high in unsaturated fat.
#
# Journal Article
# 4100347
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4100347&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Incidence of cancer in men on a diet high in polyunsaturated fat.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 4681896
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4681896&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Increased prevalence of cholelithiasis in men ingesting a serum-cholesterol-lowering diet.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 14226395
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14226395&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# EFFECT OF LONG-TERM FEEDING OF VARIOUS FATS ON WHOLE BLOOD CLOTTING TIMES IN MEN.
#
# Journal Article
# 14575938
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14575938&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Implementation of the Women's Health Initiative study design.
#
# Journal Article Research Support, U.S. Gov't, P.H.S.
# 14575944
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14575944&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Outcomes ascertainment and adjudication methods in the Women's Health Initiative.
#
# Journal Article
# 14575939
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14575939&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# The Women's Health Initiative recruitment methods and results.
#
# Journal Article
# 14575941
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=14575941&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# The Women's Health Initiative Dietary Modification trial: overview and baseline characteristics of participants.
#
# Journal Article
# 4599980
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4599980&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Effect of antihypertensive treatment on stroke recurrence. Hypertension-Stroke Cooperative Study Group.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# 4862069
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4862069&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Effects of treatment on morbidity in hypertension. Results in patients with diastolic blood pressures averaging 115 through 129 mm Hg.
#
# Clinical Trial Comparative Study Journal Article Randomized Controlled Trial
# 4914579
# https://eutils.ncbi.nlm.nih.gov/entrez/eutils/efetch.fcgi?db=pubmed&id=4914579&retmode=xml&WebEnv=%3Cwebenv%20string%3E&usehistory=y
# Effects of treatment on morbidity in hypertension. II. Results in patients with diastolic blood pressure averaging 90 through 114 mm Hg.
#
# Clinical Trial Journal Article Randomized Controlled Trial
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-9-1ec766268d08> in <module>()
#      89
#      90 df = DataFrame({'PMID': PMID_list , 'Article Title': ArticleTitle_list, 'Abstract': Abstract_list,
# ---> 91                 'Publication Type': PublicationType_list})
#      92 df = df[['PMID','Article Title', 'Abstract', 'Publication Type']]
#      93
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in __init__(self, data, index, columns, dtype, copy)
#     328                                  dtype=dtype, copy=copy)
#     329         elif isinstance(data, dict):
# --> 330             mgr = self._init_dict(data, index, columns, dtype=dtype)
#     331         elif isinstance(data, ma.MaskedArray):
#     332             import numpy.ma.mrecords as mrecords
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _init_dict(self, data, index, columns, dtype)
#     459             arrays = [data[k] for k in keys]
#     460
# --> 461         return _arrays_to_mgr(arrays, data_names, index, columns, dtype=dtype)
#     462
#     463     def _init_ndarray(self, values, index, columns, dtype=None, copy=False):
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in _arrays_to_mgr(arrays, arr_names, index, columns, dtype)
#    6161     # figure out the index, if necessary
#    6162     if index is None:
# -> 6163         index = extract_index(arrays)
#    6164     else:
#    6165         index = _ensure_index(index)
#
# ~\Anaconda3\lib\site-packages\pandas\core\frame.py in extract_index(data)
#    6209             lengths = list(set(raw_lengths))
#    6210             if len(lengths) > 1:
# -> 6211                 raise ValueError('arrays must all be same length')
#    6212
#    6213             if have_dicts:
#
# ValueError: arrays must all be same length
